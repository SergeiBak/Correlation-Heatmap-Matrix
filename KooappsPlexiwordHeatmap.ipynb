# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heatmap1.csv")
df.head()
# Out:
#    Ad_Viewed  Banner_Ad_Viewed  Interstitial_Ad_Viewed  Complete_Level  \
# 0        221               317                     335             379
# 1        222               370                     367             404
# 2        193               284                     336             355
# 3        200               287                     328             368
# 4        223               301                     343             359
#
#    Soft_Currency_Purchase  Hard_Currency_Purchase  No_More_Puzzles  \
# 0                     335                      30               26
# 1                     329                      46               26
# 2                     300                      43               23
# 3                     306                      39               25
# 4                     327                      41               23
#
#    App_Launch  Use_Boost  Rate_Me
# 0         739        316      116
# 1         998        312      102
# ...

# %%
df.columns
# Out:
# Index(['Ad_Viewed', 'Banner_Ad_Viewed', 'Interstitial_Ad_Viewed',
#        'Complete_Level', 'Soft_Currency_Purchase', 'Hard_Currency_Purchase',
#        'No_More_Puzzles', 'App_Launch', 'Use_Boost', 'Rate_Me'],
#       dtype='object')

# %%
cor = df.corr()
cor
# Out:
#                         Ad_Viewed  Banner_Ad_Viewed  Interstitial_Ad_Viewed  \
# Ad_Viewed                1.000000          0.588289                0.822990
# Banner_Ad_Viewed         0.588289          1.000000                0.756853
# Interstitial_Ad_Viewed   0.822990          0.756853                1.000000
# Complete_Level           0.835855          0.756096                0.909846
# Soft_Currency_Purchase   0.887660          0.669684                0.858884
# Hard_Currency_Purchase   0.368051          0.374002                0.417402
# No_More_Puzzles          0.631286          0.480733                0.612343
# App_Launch               0.628152          0.878065                0.756287
# Use_Boost                0.902905          0.654129                0.844295
# Rate_Me                  0.659163          0.613115                0.760811
#
#                         Complete_Level  Soft_Currency_Purchase  \
# Ad_Viewed                     0.835855                0.887660
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data = cor, annot = True)
# Out:
# <AxesSubplot:>
